# %% [markdown]
# <a href="https://colab.research.google.com/github/muskaan0409/to_do_list/blob/main/to_do_list.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
tasks=[]
while True:
  print("\n--- TO DO APP ---")
  print("1. Add Task")
  print("2. View Tasks")
  print("3. Delete Task")
  print("4. Exit")
  choice = input("Enter your choice (1-4): ")
  if choice == "1":
    task = input("Enter a new task: ")
    tasks.append(task)
    print("Task added successfully!")
  elif choice == "2":
    if len(tasks) == 0:
      print("No tasks available.")
    else:
      print("\nYour Tasks:")
      for i in range(len(tasks)):
        print(f"{i + 1}. {tasks[i]}")
  elif choice == "3":
    if len(tasks) == 0:
      print("No tasks to delete.")
    else:
      for i in range(len(tasks)):
        print(f"{i + 1}. {tasks[i]}")
        delete_task = int(input("Enter task number to delete: "))
        if delete_task > 0 and delete_task <= len(tasks):
          removed = tasks.pop(delete_task - 1)
          print(f"Removed task: {removed}")
  elif choice == "4":
    print("Exiting To-Do App. Goodbye!")
    break
# Out:
# --- TO DO APP ---
# 1. Add Task
# 2. View Tasks
# 3. Delete Task
# 4. Exit
# Enter your choice (1-4): 1
# Enter a new task: kiss me
# Task added successfully!
#
# --- TO DO APP ---
# 1. Add Task
# 2. View Tasks
# 3. Delete Task
# 4. Exit
# Enter your choice (1-4): 2
#
# Your Tasks:
# 1. kiss me
#
# --- TO DO APP ---
# 1. Add Task
# 2. View Tasks
# 3. Delete Task
# 4. Exit
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-2141213876.py in <cell line: 0>()
#       6   print("3. Delete Task")
#       7   print("4. Exit")
# ----> 8   choice = input("Enter your choice (1-4): ")
#       9   if choice == "1":
#      10     task = input("Enter a new task: ")
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
# ...
